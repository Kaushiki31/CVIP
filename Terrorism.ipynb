# %% [markdown]
# ## Importing required Libraries

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading csv file

# %%
data = pd.read_csv('globalterrorism.csv', encoding='ISO-8859-1')
data.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
# 5  1.970010e+11   1970       1     1        NaN         0        NaN      217
# 6  1.970010e+11   1970       1     2        NaN         0        NaN      218
# 7  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 8  1.970010e+11   1970       1     2        NaN         0        NaN      217
# 9  1.970010e+11   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# 2         Philippines       5  ...
# 3              Greece       8  ...
# 4               Japan       4  ...
# 5       United States       1  ...
# 6             Uruguay       3  ...
# 7       United States       1  ...
# 8       United States       1  ...
# 9       United States       1  ...
#
#                                             addnotes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  The Cairo Chief of Police, William Petersen, r...
# 6                                                NaN
# 7  Damages were estimated to be between $20,000-$...
# 8  The New Years Gang issue a communiqué to a loc...
# 9  Karl Armstrong's girlfriend, Lynn Schultz, dro...
#
#                                               scite1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Police Chief Quits," Washington Post, January...
# 6                                                NaN
# 7  Committee on Government Operations United Stat...
# 8  Tom Bates, "Rads: The 1970 Bombing of the Army...
# 9  Committee on Government Operations United Stat...
#
#                                               scite2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                NaN
# 7  Christopher Hewitt, "Political Violence and Te...
# 8  David Newman, Sandra Sutherland, and Jon Stewa...
# 9  Tom Bates, "Rads: The 1970 Bombing of the Army...
#
#                                               scite3        dbsource  INT_LOG  \
# 0                                                NaN            PGIS        0
# 1                                                NaN            PGIS        0
# 2                                                NaN            PGIS       -9
# 3                                                NaN            PGIS       -9
# 4                                                NaN            PGIS       -9
# 5  Christopher Hewitt, "Political Violence and Te...  Hewitt Project       -9
# 6                                                NaN            PGIS        0
# 7                                                NaN  Hewitt Project       -9
# 8  The Wisconsin Cartographers' Guild, "Wisconsin...  Hewitt Project        0
# 9  David Newman, Sandra Sutherland, and Jon Stewa...  Hewitt Project        0
#
#    INT_IDEO INT_MISC INT_ANY  related
# 0         0        0       0      NaN
# 1         1        1       1      NaN
# 2        -9        1       1      NaN
# 3        -9        1       1      NaN
# 4        -9        1       1      NaN
# 5        -9        0      -9      NaN
# 6         0        0       0      NaN
# 7        -9        0      -9      NaN
# 8         0        0       0      NaN
# 9         0        0       0      NaN
#
# [10 rows x 135 columns]

# %% [markdown]
# ## Checking missing values

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df = data[['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 'suicide', 'attacktype1_txt', 'targtype1_txt', 'target1', 'nkill','success']]

# %%
df.head(10)
# Out:
#         eventid  iyear  imonth  iday         country_txt  \
# 0  1.970000e+11   1970       7     2  Dominican Republic
# 1  1.970000e+11   1970       0     0              Mexico
# 2  1.970010e+11   1970       1     0         Philippines
# 3  1.970010e+11   1970       1     0              Greece
# 4  1.970010e+11   1970       1     0               Japan
# 5  1.970010e+11   1970       1     1       United States
# 6  1.970010e+11   1970       1     2             Uruguay
# 7  1.970010e+11   1970       1     2       United States
# 8  1.970010e+11   1970       1     2       United States
# 9  1.970010e+11   1970       1     3       United States
#
#                     region_txt  suicide                 attacktype1_txt  \
# 0  Central America & Caribbean        0                   Assassination
# 1                North America        0     Hostage Taking (Kidnapping)
# 2               Southeast Asia        0                   Assassination
# 3               Western Europe        0               Bombing/Explosion
# 4                    East Asia        0  Facility/Infrastructure Attack
# 5                North America        0                   Armed Assault
# 6                South America        0                   Assassination
# 7                North America        0               Bombing/Explosion
# 8                North America        0  Facility/Infrastructure Attack
# 9                North America        0  Facility/Infrastructure Attack
#
#                  targtype1_txt  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
# 5                       Police
# 6                       Police
# 7                    Utilities
# 8                     Military
# 9         Government (General)
#
#                                              target1  nkill  success
# 0                                       Julio Guzman    1.0        1
# 1                            Nadine Chaval, daughter    0.0        1
# 2                                           Employee    1.0        1
# 3                                       U.S. Embassy    NaN        1
# 4                                     U.S. Consulate    NaN        1
# 5                          Cairo Police Headquarters    0.0        1
# 6  Juan Maria de Lucah/Chief of Directorate of in...    0.0        0
# 7                                    Edes Substation    0.0        1
# 8  R.O.T.C. offices at University of Wisconsin, M...    0.0        1
# 9  Selective Service Headquarters in Madison Wisc...    0.0        1

# %%
df.isnull().sum()
# Out:
# eventid                0
# iyear                  0
# imonth                 0
# iday                   0
# country_txt            0
# region_txt             0
# suicide                0
# attacktype1_txt        0
# targtype1_txt          0
# target1              636
# nkill              10313
# success                0
# dtype: int64

# %%
df['target1'] = df['target1'].fillna('Not Known')
df['nkill'] = df['nkill'].fillna(0)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# country_txt        0
# region_txt         0
# suicide            0
# attacktype1_txt    0
# targtype1_txt      0
# target1            0
# nkill              0
# success            0
# dtype: int64

# %%
df.head(10)
# Out:
#         eventid  iyear  imonth  iday         country_txt  \
# 0  1.970000e+11   1970       7     2  Dominican Republic
# 1  1.970000e+11   1970       0     0              Mexico
# 2  1.970010e+11   1970       1     0         Philippines
# 3  1.970010e+11   1970       1     0              Greece
# 4  1.970010e+11   1970       1     0               Japan
# 5  1.970010e+11   1970       1     1       United States
# 6  1.970010e+11   1970       1     2             Uruguay
# 7  1.970010e+11   1970       1     2       United States
# 8  1.970010e+11   1970       1     2       United States
# 9  1.970010e+11   1970       1     3       United States
#
#                     region_txt  suicide                 attacktype1_txt  \
# 0  Central America & Caribbean        0                   Assassination
# 1                North America        0     Hostage Taking (Kidnapping)
# 2               Southeast Asia        0                   Assassination
# 3               Western Europe        0               Bombing/Explosion
# 4                    East Asia        0  Facility/Infrastructure Attack
# 5                North America        0                   Armed Assault
# 6                South America        0                   Assassination
# 7                North America        0               Bombing/Explosion
# 8                North America        0  Facility/Infrastructure Attack
# 9                North America        0  Facility/Infrastructure Attack
#
#                  targtype1_txt  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
# 5                       Police
# 6                       Police
# 7                    Utilities
# 8                     Military
# 9         Government (General)
#
#                                              target1  nkill  success
# 0                                       Julio Guzman    1.0        1
# 1                            Nadine Chaval, daughter    0.0        1
# 2                                           Employee    1.0        1
# 3                                       U.S. Embassy    0.0        1
# 4                                     U.S. Consulate    0.0        1
# 5                          Cairo Police Headquarters    0.0        1
# 6  Juan Maria de Lucah/Chief of Directorate of in...    0.0        0
# 7                                    Edes Substation    0.0        1
# 8  R.O.T.C. offices at University of Wisconsin, M...    0.0        1
# 9  Selective Service Headquarters in Madison Wisc...    0.0        1

# %% [markdown]
# ## Plotting the required graph

# %%
attacks = df.groupby('iyear').size().reset_index(name='count')

# %%
sns.lineplot(x='iyear', y='count',color='red', data=attacks)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Number of terrorist attacks in world')
plt.show()

# %%
type_attacks = df.groupby(['country_txt','nkill']).size().reset_index(name='count').sort_values(by='count',ascending=True)

# %%
sns.barplot(x='country_txt', y='nkill', data=type_attacks.head(20))
plt.xlabel('Country')
plt.ylabel('Number of Kills')
plt.title('Number of kills in top countries')
plt.show()

# %%
highest_attacks = df.groupby(['country_txt']).size().reset_index(name='count').sort_values(by='count',ascending=False)

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='country_txt', y='count', data=highest_attacks.head(10))
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
plt.title('Number of Countries with Highest Attacks')
plt.show()

# %%
year = df.groupby(['iyear','country_txt']).size().reset_index(name='count').sort_values(by='count',ascending=False)

# %%
plt.figure(figsize=(20,10))
sns.relplot(x='iyear', y='count',hue='country_txt' ,data=year.head(50))
plt.xlabel('Year')
plt.ylabel('Number of Terrorist Attacks')
plt.title('Name of Countries with Highest Attacks on the Years')
plt.show()

# %%
success = df.groupby(['success']).size().reset_index(name='count').sort_values(by='count',ascending=False)

# %%
sns.barplot(x='success', y='count',data=success.head(50))
plt.xlabel('Success Rate')
plt.ylabel('Number of Attacks')
plt.title('Total Success and Unsuccessful Terrorist Attacks')
plt.show()

# %%
methods = df.groupby(['success','attacktype1_txt']).size().reset_index(name='count').sort_values(by='count',ascending=False)

# %%
sns.barplot(x='success', y='count',hue='attacktype1_txt', data=methods.head(10))
plt.xlabel('Success Rate')
plt.ylabel('Number of Attacks')
plt.title('Success Rates of Different Methods')
plt.show()

# %% [markdown]
# ## Building Our Machine Learning Model

# %%
df.head(20)
# Out:
#          eventid  iyear  imonth  iday         country_txt  \
# 0   1.970000e+11   1970       7     2  Dominican Republic
# 1   1.970000e+11   1970       0     0              Mexico
# 2   1.970010e+11   1970       1     0         Philippines
# 3   1.970010e+11   1970       1     0              Greece
# 4   1.970010e+11   1970       1     0               Japan
# 5   1.970010e+11   1970       1     1       United States
# 6   1.970010e+11   1970       1     2             Uruguay
# 7   1.970010e+11   1970       1     2       United States
# 8   1.970010e+11   1970       1     2       United States
# 9   1.970010e+11   1970       1     3       United States
# 10  1.970010e+11   1970       1     1       United States
# 11  1.970010e+11   1970       1     6       United States
# 12  1.970010e+11   1970       1     8               Italy
# 13  1.970010e+11   1970       1     9       United States
# 14  1.970010e+11   1970       1     9       United States
# 15  1.970010e+11   1970       1    10  East Germany (GDR)
# 16  1.970010e+11   1970       1    11            Ethiopia
# 17  1.970010e+11   1970       1    12       United States
# 18  1.970010e+11   1970       1    12       United States
# 19  1.970010e+11   1970       1    13       United States
#
#                      region_txt  suicide                 attacktype1_txt  \
# 0   Central America & Caribbean        0                   Assassination
# 1                 North America        0     Hostage Taking (Kidnapping)
# 2                Southeast Asia        0                   Assassination
# 3                Western Europe        0               Bombing/Explosion
# 4                     East Asia        0  Facility/Infrastructure Attack
# 5                 North America        0                   Armed Assault
# 6                 South America        0                   Assassination
# 7                 North America        0               Bombing/Explosion
# 8                 North America        0  Facility/Infrastructure Attack
# 9                 North America        0  Facility/Infrastructure Attack
# 10                North America        0               Bombing/Explosion
# 11                North America        0  Facility/Infrastructure Attack
# 12               Western Europe        0                       Hijacking
# 13                North America        0  Facility/Infrastructure Attack
# 14                North America        0  Facility/Infrastructure Attack
# 15               Eastern Europe        0               Bombing/Explosion
# 16           Sub-Saharan Africa        0                         Unknown
# 17                North America        0               Bombing/Explosion
# 18                North America        0               Bombing/Explosion
# 19                North America        0  Facility/Infrastructure Attack
#
#                   targtype1_txt  \
# 0   Private Citizens & Property
# 1       Government (Diplomatic)
# 2           Journalists & Media
# 3       Government (Diplomatic)
# 4       Government (Diplomatic)
# 5                        Police
# 6                        Police
# 7                     Utilities
# 8                      Military
# 9          Government (General)
# 10                     Military
# 11                     Military
# 12          Airports & Aircraft
# 13         Government (General)
# 14                     Business
# 15         Government (General)
# 16                     Military
# 17      Educational Institution
# 18                     Business
# 19                     Business
#
#                                               target1  nkill  success
# 0                                        Julio Guzman    1.0        1
# 1                             Nadine Chaval, daughter    0.0        1
# 2                                            Employee    1.0        1
# 3                                        U.S. Embassy    0.0        1
# 4                                      U.S. Consulate    0.0        1
# 5                           Cairo Police Headquarters    0.0        1
# 6   Juan Maria de Lucah/Chief of Directorate of in...    0.0        0
# 7                                     Edes Substation    0.0        1
# 8   R.O.T.C. offices at University of Wisconsin, M...    0.0        1
# 9   Selective Service Headquarters in Madison Wisc...    0.0        1
# 10                            Badger Army ammo depot.    0.0        0
# 11           Army Recruiting Station, Denver Colorado    0.0        1
# 12                              Flight 802 Boeing 707    0.0        1
# 13    Packard Properties building of Detroit Michigan    0.0        1
# 14                                      Baker's Store    0.0        1
# 15                 Jurists Ball (Palais au Frankturm)    0.0        1
# 16                                            Soldier    1.0        1
# 17                          James Madison High School    0.0        1
# 18  General Electric factory in Rio Grande Puerto ...    0.0        1
# 19       Fuson's Department Store, Seattle Washington    0.0        1

# %% [markdown]
# ## Using Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['country_txt'] = le.fit_transform(df['country_txt'])
df['region_txt'] = le.fit_transform(df['region_txt'])
df['attacktype1_txt'] = le.fit_transform(df['attacktype1_txt'])
df['targtype1_txt'] = le.fit_transform(df['targtype1_txt'])

# %%
df.head(20)
# Out:
#          eventid  iyear  imonth  iday  country_txt  region_txt  suicide  \
# 0   1.970000e+11   1970       7     2           47           1        0
# 1   1.970000e+11   1970       0     0          116           6        0
# 2   1.970010e+11   1970       1     0          140           9        0
# 3   1.970010e+11   1970       1     0           68          11        0
# 4   1.970010e+11   1970       1     0           90           3        0
# 5   1.970010e+11   1970       1     1          189           6        0
# 6   1.970010e+11   1970       1     2          190           7        0
# 7   1.970010e+11   1970       1     2          189           6        0
# 8   1.970010e+11   1970       1     2          189           6        0
# 9   1.970010e+11   1970       1     3          189           6        0
# 10  1.970010e+11   1970       1     1          189           6        0
# 11  1.970010e+11   1970       1     6          189           6        0
# 12  1.970010e+11   1970       1     8           87          11        0
# 13  1.970010e+11   1970       1     9          189           6        0
# 14  1.970010e+11   1970       1     9          189           6        0
# 15  1.970010e+11   1970       1    10           48           4        0
# 16  1.970010e+11   1970       1    11           56          10        0
# 17  1.970010e+11   1970       1    12          189           6        0
# 18  1.970010e+11   1970       1    12          189           6        0
# 19  1.970010e+11   1970       1    13          189           6        0
#
#     attacktype1_txt  targtype1_txt  \
# 0                 1             13
# 1                 6              5
# 2                 1              7
# 3                 2              5
# 4                 3              5
# 5                 0             12
# 6                 1             12
# 7                 2             20
# 8                 3              9
# 9                 3              6
# 10                2              9
# 11                3              9
# 12                4              1
# 13                3              6
# 14                3              2
# 15                2              6
# 16                8              9
# 17                2              3
# 18                2              2
# 19                3              2
#
#                                               target1  nkill  success
# 0                                        Julio Guzman    1.0        1
# 1                             Nadine Chaval, daughter    0.0        1
# 2                                            Employee    1.0        1
# 3                                        U.S. Embassy    0.0        1
# 4                                      U.S. Consulate    0.0        1
# 5                           Cairo Police Headquarters    0.0        1
# 6   Juan Maria de Lucah/Chief of Directorate of in...    0.0        0
# 7                                     Edes Substation    0.0        1
# 8   R.O.T.C. offices at University of Wisconsin, M...    0.0        1
# 9   Selective Service Headquarters in Madison Wisc...    0.0        1
# 10                            Badger Army ammo depot.    0.0        0
# 11           Army Recruiting Station, Denver Colorado    0.0        1
# 12                              Flight 802 Boeing 707    0.0        1
# 13    Packard Properties building of Detroit Michigan    0.0        1
# 14                                      Baker's Store    0.0        1
# 15                 Jurists Ball (Palais au Frankturm)    0.0        1
# 16                                            Soldier    1.0        1
# 17                          James Madison High School    0.0        1
# 18  General Electric factory in Rio Grande Puerto ...    0.0        1
# 19       Fuson's Department Store, Seattle Washington    0.0        1

# %%
x = df[['country_txt','region_txt','attacktype1_txt','targtype1_txt','nkill']]

# %%
x.head()
# Out:
#    country_txt  region_txt  attacktype1_txt  targtype1_txt  nkill
# 0           47           1                1             13    1.0
# 1          116           6                6              5    0.0
# 2          140           9                1              7    1.0
# 3           68          11                2              5    0.0
# 4           90           3                3              5    0.0

# %%
y = df['success']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: success, dtype: int64

# %%
x.shape
# Out:
# (181691, 5)

# %%
y.shape
# Out:
# (181691,)

# %% [markdown]
# ## splitting our model into training and testing dataset

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
xtrain.shape , ytrain.shape , xtest.shape , ytest.shape
# Out:
# ((145352, 5), (145352,), (36339, 5), (36339,))

# %% [markdown]
# ## Training our model using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.score(xtest, ytest) # Score not accurate enough
# Out:
# 0.8905308346404689

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
xtrain_new = scaler.fit_transform(xtrain)
xtest_new = scaler.transform(xtest)

# %%
model.fit(xtrain_new,ytrain)
# Out:
# LogisticRegression()

# %%
model.score(xtest_new,ytest)
# Out:
# 0.8905308346404689

# %% [markdown]
# ### Score not accurate enough, so we will be trying other method

# %% [markdown]
# ## Training our model using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=10,random_state=42)

# %%
clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=42)

# %%
clf.score(xtest,ytest) # Till now best score
# Out:
# 0.9216544208701395

# %% [markdown]
# ## Confusion matrix

# %%
y_pred=clf.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix=(ytest,y_pred)
cm
# Out:
# (83552     1
#  30191     1
#  51303     1
#  73581     1
#  17703     0
#           ..
#  161764    1
#  82466     1
#  26466     1
#  77743     0
#  43861     0
#  Name: success, Length: 36339, dtype: int64,
#  array([1, 1, 0, ..., 1, 0, 1], dtype=int64))
